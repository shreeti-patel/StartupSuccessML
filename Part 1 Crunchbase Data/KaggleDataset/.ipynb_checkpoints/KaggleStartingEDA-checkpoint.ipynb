# %%
import pandas as pd
import numpy as np

# %%
raw_data  = pd.read_csv("startup data.csv")
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                923 non-null    int64
#  1   state_code                923 non-null    object
#  2   latitude                  923 non-null    float64
#  3   longitude                 923 non-null    float64
#  4   zip_code                  923 non-null    object
#  5   id                        923 non-null    object
#  6   city                      923 non-null    object
#  7   Unnamed: 6                430 non-null    object
#  8   name                      923 non-null    object
#  9   labels                    923 non-null    int64
#  10  founded_at                923 non-null    object
#  11  closed_at                 335 non-null    object
#  12  first_funding_at          923 non-null    object
# ...

# %%
data = raw_data.drop(['Unnamed: 0','Unnamed: 6','latitude','longitude','zip_code','id','name','object_id'], axis = 1)
data
# Out:
#     state_code           city  labels founded_at  closed_at first_funding_at  \
# 0           CA      San Diego       1   1/1/2007        NaN         4/1/2009
# 1           CA      Los Gatos       1   1/1/2000        NaN        2/14/2005
# 2           CA      San Diego       1  3/18/2009        NaN        3/30/2010
# 3           CA      Cupertino       1   1/1/2002        NaN        2/17/2005
# 4           CA  San Francisco       0   8/1/2010  10/1/2012         8/1/2010
# ..         ...            ...     ...        ...        ...              ...
# 918         CA  San Francisco       1   1/1/2009        NaN         7/9/2009
# 919         MA     Burlington       0   1/1/1998  6/25/2008         4/1/2005
# 920         CA      Sunnyvale       0   1/1/1999  6/17/2012        6/29/2007
# 921         CA  San Francisco       1   1/1/2009        NaN        10/5/2009
# 922         CA    Santa Clara       1   1/1/2003        NaN        2/13/2006
#
# ...

# %%
print(data['state_code'].equals(data['state_code.1']))
df = data.loc[data['state_code'] != data['state_code.1']]
df
# Out:
# False
#     state_code        city  labels founded_at closed_at first_funding_at  \
# 515         CA  Menlo Park       0   1/1/2005  9/1/2010         3/1/2007
#
#     last_funding_at  age_first_funding_year  age_last_funding_year  \
# 515       4/15/2008                  2.1616                 3.2877
#
#      age_first_milestone_year  ...  is_othercategory  has_VC  has_angel  \
# 515                    3.4986  ...                 1       0          0
#
#      has_roundA  has_roundB has_roundC  has_roundD  avg_participants  \
# 515           1           1          0           0               2.5
#
#      is_top500  status
# 515          1  closed
#
# [1 rows x 41 columns]
