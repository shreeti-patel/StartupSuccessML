# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from itertools import chain, combinations
from sklearn.ensemble import RandomForestRegressor

import numpy as np

# %%
df = pd.read_pickle('FE_cleaned_PrivCo_data.pkl')
print(df.info())
print(df.columns)
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5997 entries, 0 to 5996
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PrivCo_ID               5997 non-null   int64
#  1   profile_type            5997 non-null   object
#  2   classification          5997 non-null   object
#  3   status                  5997 non-null   object
#  4   PE_Backed               5997 non-null   object
#  5   VC_Backed               5997 non-null   object
#  6   year_founded            5997 non-null   int64
#  7   City                    5948 non-null   object
#  8   State                   5933 non-null   object
#  9   Country                 5997 non-null   object
#  10  Zip                     4796 non-null   object
#  11  Industry_PICS           5980 non-null   object
#  12  Keywords                5812 non-null   object
#  13  sic                     201 non-null    object
#  14  naics                   564 non-null    object
#  15  Company_Tags            3631 non-null   object
#  16  fiscal_month            5997 non-null   int64
#  17  fiscal_day              5997 non-null   int64
#  18  Total_Round             5997 non-null   float64
#  19  index_total_funding     5997 non-null   float64
#  20  Latest_Valuation        5545 non-null   float64
#  21  Latest_Valuation_Year   5545 non-null   float64
#  22  1 Year Revenue Growth   3928 non-null   float64
#  23  3 Year Revenue Growth   5997 non-null   float64
#  24  1 Year Employee Growth  2117 non-null   float64
#  25  3 Year Employee Growth  549 non-null    float64
#  26  2023 Revenue            5997 non-null   float64
#  27  2022 Revenue            5997 non-null   float64
#  28  2021 Revenue            5997 non-null   float64
#  29  2020 Revenue            5997 non-null   float64
#  30  2019 Revenue            5997 non-null   float64
#  31  2018 Revenue            291 non-null    float64
#  32  2017 Revenue            160 non-null    float64
#  33  2023 Employees          2725 non-null   float64
#  34  2022 Employees          2314 non-null   float64
#  35  2021 Employees          2138 non-null   float64
#  36  2020 Employees          1212 non-null   float64
#  37  2019 Employees          612 non-null    float64
#  38  2018 Employees          292 non-null    float64
#  39  2017 Employees          157 non-null    float64
#  40  2023 EBITDA             2170 non-null   float64
#  41  2022 EBITDA             1391 non-null   float64
#  42  2021 EBITDA             855 non-null    float64
#  43  2020 EBITDA             506 non-null    float64
#  44  2019 EBITDA             238 non-null    float64
#  45  2018 EBITDA             5997 non-null   float64
#  46  2017 EBITDA             5997 non-null   float64
#  47  2023 EV                 2174 non-null   float64
#  48  2022 EV                 1378 non-null   float64
#  49  2021 EV                 842 non-null    float64
#  50  2020 EV                 485 non-null    float64
#  51  2019 EV                 218 non-null    float64
#  52  2018 EV                 142 non-null    float64
#  53  2017 EV                 130 non-null    float64
#  54  2023 Net Income         2170 non-null   float64
#  55  2022 Net Income         1393 non-null   float64
#  56  2021 Net Income         846 non-null    float64
#  57  2020 Net Income         33 non-null     float64
#  58  2019 Net Income         31 non-null     float64
#  59  2018 Net Income         7 non-null      float64
#  60  2017 Net Income         0 non-null      float64
#  61  CAGR                    5997 non-null   float64
#  62  Latest EBITDA           5997 non-null   float64
#  63  Latest EV               5997 non-null   float64
#  64  Latest Net Income       5997 non-null   float64
# dtypes: float64(47), int64(4), object(14)
# memory usage: 3.0+ MB
# None
# Index(['PrivCo_ID', 'profile_type', 'classification', 'status', 'PE_Backed',
#        'VC_Backed', 'year_founded', 'City', 'State', 'Country', 'Zip',
#        'Industry_PICS', 'Keywords', 'sic', 'naics', 'Company_Tags',
#        'fiscal_month', 'fiscal_day', 'Total_Round', 'index_total_funding',
#        'Latest_Valuation', 'Latest_Valuation_Year', '1 Year Revenue Growth',
#        '3 Year Revenue Growth', '1 Year Employee Growth',
#        '3 Year Employee Growth', '2023 Revenue', '2022 Revenue',
#        '2021 Revenue', '2020 Revenue', '2019 Revenue', '2018 Revenue',
#        '2017 Revenue', '2023 Employees', '2022 Employees', '2021 Employees',
#        '2020 Employees', '2019 Employees', '2018 Employees', '2017 Employees',
#        '2023 EBITDA', '2022 EBITDA', '2021 EBITDA', '2020 EBITDA',
#        '2019 EBITDA', '2018 EBITDA', '2017 EBITDA', '2023 EV', '2022 EV',
#        '2021 EV', '2020 EV', '2019 EV', '2018 EV', '2017 EV',
#        '2023 Net Income', '2022 Net Income', '2021 Net Income',
#        '2020 Net Income', '2019 Net Income', '2018 Net Income',
#        '2017 Net Income', 'CAGR', 'Latest EBITDA', 'Latest EV',
#        'Latest Net Income'],
#       dtype='object')
# (5997, 65)

# %% [markdown]
# ## One Hot Encode the low cardinality categorical data

# %%
columns_to_encode = ['PE_Backed','VC_Backed']
df = pd.get_dummies(df, columns=columns_to_encode)
df = df.drop(['PE_Backed_No', 'VC_Backed_No'], axis=1)
df['PE_Backed_Yes'] = df['PE_Backed_Yes'].astype('int')
df['VC_Backed_Yes'] = df['VC_Backed_Yes'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5997 entries, 0 to 5996
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PrivCo_ID               5997 non-null   int64
#  1   profile_type            5997 non-null   object
#  2   classification          5997 non-null   object
#  3   status                  5997 non-null   object
#  4   year_founded            5997 non-null   int64
#  5   City                    5948 non-null   object
#  6   State                   5933 non-null   object
#  7   Country                 5997 non-null   object
#  8   Zip                     4796 non-null   object
#  9   Industry_PICS           5980 non-null   object
#  10  Keywords                5812 non-null   object
#  11  sic                     201 non-null    object
#  12  naics                   564 non-null    object
#  13  Company_Tags            3631 non-null   object
#  14  fiscal_month            5997 non-null   int64
#  15  fiscal_day              5997 non-null   int64
#  16  Total_Round             5997 non-null   float64
#  17  index_total_funding     5997 non-null   float64
#  18  Latest_Valuation        5545 non-null   float64
#  19  Latest_Valuation_Year   5545 non-null   float64
#  20  1 Year Revenue Growth   3928 non-null   float64
#  21  3 Year Revenue Growth   5997 non-null   float64
#  22  1 Year Employee Growth  2117 non-null   float64
#  23  3 Year Employee Growth  549 non-null    float64
#  24  2023 Revenue            5997 non-null   float64
#  25  2022 Revenue            5997 non-null   float64
#  26  2021 Revenue            5997 non-null   float64
#  27  2020 Revenue            5997 non-null   float64
#  28  2019 Revenue            5997 non-null   float64
#  29  2018 Revenue            291 non-null    float64
#  30  2017 Revenue            160 non-null    float64
#  31  2023 Employees          2725 non-null   float64
#  32  2022 Employees          2314 non-null   float64
#  33  2021 Employees          2138 non-null   float64
#  34  2020 Employees          1212 non-null   float64
#  35  2019 Employees          587 non-null    float64
#  36  2018 Employees          280 non-null    float64
#  37  2017 Employees          156 non-null    float64
#  38  2023 EBITDA             2009 non-null   float64
#  39  2022 EBITDA             1306 non-null   float64
#  40  2021 EBITDA             798 non-null    float64
#  41  2020 EBITDA             465 non-null    float64
#  42  2019 EBITDA             223 non-null    float64
#  43  2018 EBITDA             5545 non-null   float64
#  44  2017 EBITDA             5545 non-null   float64
#  45  2023 EV                 2013 non-null   float64
#  46  2022 EV                 1311 non-null   float64
#  47  2021 EV                 798 non-null    float64
#  48  2020 EV                 453 non-null    float64
#  49  2019 EV                 211 non-null    float64
#  50  2018 EV                 140 non-null    float64
#  51  2017 EV                 130 non-null    float64
#  52  2023 Net Income         2009 non-null   float64
#  53  2022 Net Income         1306 non-null   float64
#  54  2021 Net Income         791 non-null    float64
#  55  2020 Net Income         21 non-null     float64
#  56  2019 Net Income         20 non-null     float64
#  57  2018 Net Income         6 non-null      float64
#  58  2017 Net Income         0 non-null      float64
#  59  CAGR                    5545 non-null   float64
#  60  Latest EBITDA           5545 non-null   float64
#  61  Latest EV               5545 non-null   float64
#  62  Latest Net Income       5545 non-null   float64
#  63  PE_Backed_Yes           5545 non-null   int64
#  64  VC_Backed_Yes           5545 non-null   int64
# dtypes: float64(47), int64(6), object(12)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Define the target, y, and possible features, X

# %%
# Target
y = df['Latest_Valuation']

# Features
features = ['year_founded', 'Total_Round',
        '3 Year Revenue Growth', '2023 Revenue',
       '2022 Revenue', '2021 Revenue', '2020 Revenue', '2019 Revenue', 'CAGR',
       'Latest EBITDA', 'Latest EV', 'Latest Net Income', 'PE_Backed_Yes', 'VC_Backed_Yes']


X = df[features]

print(X.info())
print(y.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5545 entries, 1 to 5996
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year_founded           5545 non-null   int64
#  1   Total_Round            5545 non-null   float64
#  2   3 Year Revenue Growth  5545 non-null   float64
#  3   2023 Revenue           5545 non-null   float64
#  4   2022 Revenue           5545 non-null   float64
#  5   2021 Revenue           5545 non-null   float64
#  6   2020 Revenue           5545 non-null   float64
#  7   2019 Revenue           5545 non-null   float64
#  8   CAGR                   5545 non-null   float64
#  9   Latest EBITDA          5545 non-null   float64
#  10  Latest EV              5545 non-null   float64
#  11  Latest Net Income      5545 non-null   float64
#  12  PE_Backed_Yes          5545 non-null   int64
#  13  VC_Backed_Yes          5545 non-null   int64
# dtypes: float64(11), int64(3)
# memory usage: 649.8 KB
# None
# <class 'pandas.core.series.Series'>
# Int64Index: 5545 entries, 1 to 5996
# Series name: Latest_Valuation
# Non-Null Count  Dtype
# --------------  -----
# 5545 non-null   float64
# dtypes: float64(1)
# memory usage: 86.6 KB
# None

# %%
X.columns
# Out:
# Index(['year_founded', 'Total_Round', '3 Year Revenue Growth', '2023 Revenue',
#        '2022 Revenue', '2021 Revenue', '2020 Revenue', '2019 Revenue', 'CAGR',
#        'Latest EBITDA', 'Latest EV', 'Latest Net Income', 'PE_Backed_Yes',
#        'VC_Backed_Yes'],
#       dtype='object')

# %%
y = df['Latest_Valuation'].values.reshape(-1, 1)

# intialize the scalers for X and y sepreatly using minMaxScaler in range 0 to 1
scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# Scale the features and target
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Initialize the linear regression model 
model = LinearRegression()

# cross-validation this is 5-fold cross-validation
cv = KFold(n_splits=5, random_state=42, shuffle=True)

# Use negative mean absolute error to minimize MSE later
cv_scores = cross_val_score(model, X_scaled, y_scaled.ravel(), cv=cv, scoring='neg_mean_absolute_error')

# Print the scores
print("Cross-Validation Scores (Negative Mean Absolute Error):", cv_scores)
print("Average MAE:", -cv_scores.mean())  # Convert from negative to positive
# Out:
# Cross-Validation Scores (Negative Mean Absolute Error): [-0.00092359 -0.00102041 -0.00163874 -0.00118251 -0.00093126]
# Average MAE: 0.0011392997789419735

# %% [markdown]
# # Finding the best features to use

# %% [markdown]
#  ## I wanted to test all combinations of features to see which gave the best results

# %% [markdown]
# ## Loop thorugh all combinations of possible features, train a model useing only those feautes, cross validate the model and get the best Mean Absolute Error

# %% [markdown]
# ### Create funcation to get all non-empty combinations the possible features

# %%
# Function to get all non-empty combinations of a list of items
def all_subsets(ss):
    return chain(*map(lambda x: combinations(ss, x), range(1, len(ss)+1)))

# Store all subsets and thier coresponding best msein a dict
mae_dict = {}

features = ['year_founded', 'Total_Round',
        '3 Year Revenue Growth', '2023 Revenue',
       '2022 Revenue', '2021 Revenue', '2020 Revenue', '2019 Revenue', 'CAGR',
       'Latest EBITDA', 'Latest EV', 'Latest Net Income', 'PE_Backed_Yes', 'VC_Backed_Yes']

# %%
# Count number of subsets
subset_count = 0 
for subset in all_subsets(features):
    subset_count=  subset_count + 1
print(subset_count)
# Out:
# 16383

# %% [markdown]
# ## Loop thorugh each subset, train a model on that subset of features and record the Average Mean Absolute Error

# %%
# For each subset, train a cross validated model and keep the mse in the mse_dict
for subset in all_subsets(features):
    
    # Set X to the subset of features
    X = df[list(subset)]

    # y is the same 
    y = df[['Latest_Valuation']]  
    
    # Initialize two separate scalers
    scaler_X = MinMaxScaler(feature_range=(0, 1))
    scaler_y = MinMaxScaler(feature_range=(0, 1))

    # Scale the features and target
    X_scaled = scaler_X.fit_transform(X)
    y_scaled = scaler_y.fit_transform(y)

    # Initialize the linear regression model
    model = LinearRegression()

    # Prepare cross-validation (e.g., 5-fold cross-validation)
    cv = KFold(n_splits=5, random_state=42, shuffle=True)

    # Perform cross-validation
    cv_scores = cross_val_score(model, X_scaled, y_scaled.ravel(), cv=cv, scoring='neg_mean_absolute_error')
    
    avg_cv_score = -cv_scores.mean()
  
    mae_dict[subset] = avg_cv_score
    
    
best_features = min(mae_dict, key=mae_dict.get)
best_mae = mae_dict[best_features]
best_mae
# Out:
# 0.000961006485086374

# %%
best_features
# Out:
# ('Total_Round', 'Latest EV', 'VC_Backed_Yes')

# %% [markdown]
# ### Top 5 best subsets

# %%
# Sort the dictionary by its values (avg_cv_score) and get the first 5 entries
sorted_mae_dict = sorted(mae_dict.items(), key=lambda x: x[1])

# Get the top 5 subsets with the smallest avg_cv_score
top_5_subsets = sorted_mae_dict[:5]

# If you want to transform it back into a dictionary:
top_5_mae_dict = dict(top_5_subsets)

# Output the top 5 subsets and their avg_cv_scores
top_5_mae_dict
# Out:
# {('Total_Round', 'Latest EV', 'VC_Backed_Yes'): 0.000961006485086374,
#  ('Total_Round', 'CAGR', 'Latest EV', 'VC_Backed_Yes'): 0.000962252874610744,
#  ('Total_Round',
#   'Latest EBITDA',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009624292996454609,
#  ('Total_Round',
#   'CAGR',
#   'Latest EBITDA',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009636743371378047,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009648009983022189}

# %% [markdown]
# ### Print the mae_dict to see the scores of other subsets

# %%
mae_dict
# Out:
# {('year_founded',): 0.0015926628696252304,
#  ('Total_Round',): 0.0014382554374418022,
#  ('3 Year Revenue Growth',): 0.0015545475171178551,
#  ('2023 Revenue',): 0.00152658707561344,
#  ('2022 Revenue',): 0.001458037459331108,
#  ('2021 Revenue',): 0.0014411512322322641,
#  ('2020 Revenue',): 0.001550343767777287,
#  ('2019 Revenue',): 0.001514987225092749,
#  ('CAGR',): 0.0015811181038904402,
#  ('Latest EBITDA',): 0.0015476547629701258,
#  ('Latest EV',): 0.0011193447277763446,
#  ('Latest Net Income',): 0.0015306100753645691,
#  ('PE_Backed_Yes',): 0.001526307158564555,
#  ('VC_Backed_Yes',): 0.0015484391719021336,
#  ('year_founded', 'Total_Round'): 0.0014845679282539039,
#  ('year_founded', '3 Year Revenue Growth'): 0.0015779086230491273,
#  ('year_founded', '2023 Revenue'): 0.0015409888928083267,
#  ('year_founded', '2022 Revenue'): 0.0014721295387481346,
#  ('year_founded', '2021 Revenue'): 0.0014536081150821744,
#  ('year_founded', '2020 Revenue'): 0.001565148510433139,
#  ('year_founded', '2019 Revenue'): 0.0015297424795383398,
#  ('year_founded', 'CAGR'): 0.0015960773232106997,
#  ('year_founded', 'Latest EBITDA'): 0.0015603251883295768,
#  ('year_founded', 'Latest EV'): 0.0011277456208721474,
#  ('year_founded', 'Latest Net Income'): 0.0015430446961367176,
#  ('year_founded', 'PE_Backed_Yes'): 0.0015389087977465098,
#  ('year_founded', 'VC_Backed_Yes'): 0.001558203789578889,
#  ('Total_Round', '3 Year Revenue Growth'): 0.0014389349862628286,
#  ('Total_Round', '2023 Revenue'): 0.001383588399528241,
#  ('Total_Round', '2022 Revenue'): 0.001337431267125281,
#  ('Total_Round', '2021 Revenue'): 0.0013159296345397415,
#  ('Total_Round', '2020 Revenue'): 0.0014222346822303233,
#  ('Total_Round', '2019 Revenue'): 0.0013775883964840072,
#  ('Total_Round', 'CAGR'): 0.0014409211397590888,
#  ('Total_Round', 'Latest EBITDA'): 0.0014031824520862595,
#  ('Total_Round', 'Latest EV'): 0.0009841520773154755,
#  ('Total_Round', 'Latest Net Income'): 0.0013830369812430732,
#  ('Total_Round', 'PE_Backed_Yes'): 0.001421810206824881,
#  ('Total_Round', 'VC_Backed_Yes'): 0.0014167550246190815,
#  ('3 Year Revenue Growth', '2023 Revenue'): 0.0015068022089855721,
#  ('3 Year Revenue Growth', '2022 Revenue'): 0.001440332577674878,
#  ('3 Year Revenue Growth', '2021 Revenue'): 0.001420919758894,
#  ('3 Year Revenue Growth', '2020 Revenue'): 0.0015216292022720416,
#  ('3 Year Revenue Growth', '2019 Revenue'): 0.001489996033288727,
#  ('3 Year Revenue Growth', 'CAGR'): 0.001556389726393722,
#  ('3 Year Revenue Growth', 'Latest EBITDA'): 0.001524001633141437,
#  ('3 Year Revenue Growth', 'Latest EV'): 0.001108994461054001,
#  ('3 Year Revenue Growth', 'Latest Net Income'): 0.0015078646634571163,
#  ('3 Year Revenue Growth', 'PE_Backed_Yes'): 0.001507909552473088,
#  ('3 Year Revenue Growth', 'VC_Backed_Yes'): 0.0015305539838032611,
#  ('2023 Revenue', '2022 Revenue'): 0.001457723085260417,
#  ('2023 Revenue', '2021 Revenue'): 0.001426976571546762,
#  ('2023 Revenue', '2020 Revenue'): 0.0015129733950240529,
#  ('2023 Revenue', '2019 Revenue'): 0.0014733304772043313,
#  ('2023 Revenue', 'CAGR'): 0.0015303377191378804,
#  ('2023 Revenue', 'Latest EBITDA'): 0.001520939779745504,
#  ('2023 Revenue', 'Latest EV'): 0.001116204755957164,
#  ('2023 Revenue', 'Latest Net Income'): 0.001509340621600401,
#  ('2023 Revenue', 'PE_Backed_Yes'): 0.0014804916944608478,
#  ('2023 Revenue', 'VC_Backed_Yes'): 0.0014896759955742912,
#  ('2022 Revenue', '2021 Revenue'): 0.0015035150911314255,
#  ('2022 Revenue', '2020 Revenue'): 0.0014741071121019144,
#  ('2022 Revenue', '2019 Revenue'): 0.0013754627403897454,
#  ('2022 Revenue', 'CAGR'): 0.0014607683616069812,
#  ('2022 Revenue', 'Latest EBITDA'): 0.0014928880399852828,
#  ('2022 Revenue', 'Latest EV'): 0.0011295544207400512,
#  ('2022 Revenue', 'Latest Net Income'): 0.001496900266401269,
#  ('2022 Revenue', 'PE_Backed_Yes'): 0.0014115950796260498,
#  ('2022 Revenue', 'VC_Backed_Yes'): 0.0014156846360923836,
#  ('2021 Revenue', '2020 Revenue'): 0.0015167638126938384,
#  ('2021 Revenue', '2019 Revenue'): 0.0014755165592978416,
#  ('2021 Revenue', 'CAGR'): 0.0014442682638986179,
#  ('2021 Revenue', 'Latest EBITDA'): 0.0014073023865250878,
#  ('2021 Revenue', 'Latest EV'): 0.0011234470248433991,
#  ('2021 Revenue', 'Latest Net Income'): 0.0014182352924893174,
#  ('2021 Revenue', 'PE_Backed_Yes'): 0.0013912422306346355,
#  ('2021 Revenue', 'VC_Backed_Yes'): 0.00140006900671073,
#  ('2020 Revenue', '2019 Revenue'): 0.001449804746728058,
#  ('2020 Revenue', 'CAGR'): 0.0015535900435644037,
#  ('2020 Revenue', 'Latest EBITDA'): 0.0015988608502192434,
#  ('2020 Revenue', 'Latest EV'): 0.0011245245663757265,
#  ('2020 Revenue', 'Latest Net Income'): 0.0015908974136435272,
#  ('2020 Revenue', 'PE_Backed_Yes'): 0.0015006049287780785,
#  ('2020 Revenue', 'VC_Backed_Yes'): 0.0015117279942389026,
#  ('2019 Revenue', 'CAGR'): 0.0015182705594833346,
#  ('2019 Revenue', 'Latest EBITDA'): 0.001573591940161093,
#  ('2019 Revenue', 'Latest EV'): 0.0011202505097937577,
#  ('year_founded', 'CAGR', 'Latest Net Income'): 0.0015466258162970463,
#  ('year_founded', 'CAGR', 'PE_Backed_Yes'): 0.001541810448409217,
#  ('year_founded', 'CAGR', 'VC_Backed_Yes'): 0.001561435793544963,
#  ('year_founded', 'Latest EBITDA', 'Latest EV'): 0.001131810852189156,
#  ('year_founded', 'Latest EBITDA', 'Latest Net Income'): 0.0015809407445794813,
#  ('year_founded', 'Latest EBITDA', 'PE_Backed_Yes'): 0.0015067320975128908,
#  ('year_founded', 'Latest EBITDA', 'VC_Backed_Yes'): 0.0015152156640777122,
#  ('year_founded', 'Latest EV', 'Latest Net Income'): 0.0011323312064720572,
#  ('year_founded', 'Latest EV', 'PE_Backed_Yes'): 0.0010859120992991083,
#  ('year_founded', 'Latest EV', 'VC_Backed_Yes'): 0.0010356289045706285,
#  ('year_founded', 'Latest Net Income', 'PE_Backed_Yes'): 0.0014903849630841452,
#  ('year_founded', 'Latest Net Income', 'VC_Backed_Yes'): 0.0014973742614750045,
#  ('year_founded', 'PE_Backed_Yes', 'VC_Backed_Yes'): 0.0015205804923390754,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   '2023 Revenue'): 0.0013860651621534184,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   '2022 Revenue'): 0.001339745796714456,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   '2021 Revenue'): 0.0013178898469264299,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   '2020 Revenue'): 0.0014169745734782047,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   '2019 Revenue'): 0.001376420614187811,
#  ('Total_Round', '3 Year Revenue Growth', 'CAGR'): 0.0014402537347533897,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   'Latest EBITDA'): 0.0014052619735744655,
#  ('Total_Round', '3 Year Revenue Growth', 'Latest EV'): 0.0009893526290788613,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   'Latest Net Income'): 0.0013867267001414093,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   'PE_Backed_Yes'): 0.0014237103044957037,
#  ('Total_Round',
#   '3 Year Revenue Growth',
#   'VC_Backed_Yes'): 0.001418889958416095,
#  ('Total_Round', '2023 Revenue', '2022 Revenue'): 0.0013386014818061022,
#  ('Total_Round', '2023 Revenue', '2021 Revenue'): 0.0013066051270858095,
#  ('Total_Round', '2023 Revenue', '2020 Revenue'): 0.00139976760660134,
#  ('Total_Round', '2023 Revenue', '2019 Revenue'): 0.0013399888372430337,
#  ('Total_Round', '2023 Revenue', 'CAGR'): 0.0013864602876091834,
#  ('Total_Round', '2023 Revenue', 'Latest EBITDA'): 0.0013796386074388417,
#  ('Total_Round', '2023 Revenue', 'Latest EV'): 0.000993425185203001,
#  ('Total_Round', '2023 Revenue', 'Latest Net Income'): 0.0013654244779088968,
#  ('Total_Round', '2023 Revenue', 'PE_Backed_Yes'): 0.0013739580816442734,
#  ('Total_Round', '2023 Revenue', 'VC_Backed_Yes'): 0.0013658617309897467,
#  ('Total_Round', '2022 Revenue', '2021 Revenue'): 0.0014014690913640077,
#  ('Total_Round', '2022 Revenue', '2020 Revenue'): 0.0013624227734547404,
#  ('Total_Round', '2022 Revenue', '2019 Revenue'): 0.0012734834411052911,
#  ('Total_Round', '2022 Revenue', 'CAGR'): 0.0013395958339611433,
#  ('Total_Round', '2022 Revenue', 'Latest EBITDA'): 0.0013879035679096193,
#  ('Total_Round', '2022 Revenue', 'Latest EV'): 0.001000076511463162,
#  ('Total_Round', '2022 Revenue', 'Latest Net Income'): 0.0013848180651462243,
#  ('Total_Round', '2022 Revenue', 'PE_Backed_Yes'): 0.0013432380100483984,
#  ('Total_Round', '2022 Revenue', 'VC_Backed_Yes'): 0.0012968758402569593,
#  ('Total_Round', '2021 Revenue', '2020 Revenue'): 0.0014072337950011334,
#  ('Total_Round', '2021 Revenue', '2019 Revenue'): 0.0013530994532549826,
#  ('Total_Round', '2021 Revenue', 'CAGR'): 0.0013185461752490539,
#  ('Total_Round', '2021 Revenue', 'Latest EBITDA'): 0.0012968631063621523,
#  ('Total_Round', '2021 Revenue', 'Latest EV'): 0.000993898794587359,
#  ('Total_Round', '2021 Revenue', 'Latest Net Income'): 0.0013030556471200553,
#  ('Total_Round', '2021 Revenue', 'PE_Backed_Yes'): 0.001317794575426434,
#  ('Total_Round', '2021 Revenue', 'VC_Backed_Yes'): 0.0012757909113792158,
#  ('Total_Round', '2020 Revenue', '2019 Revenue'): 0.00133278338374522,
#  ('Total_Round', '2020 Revenue', 'CAGR'): 0.0014250907961434315,
#  ('Total_Round', '2020 Revenue', 'Latest EBITDA'): 0.0014805965577015141,
#  ('Total_Round', '2020 Revenue', 'Latest EV'): 0.0009940552633319899,
#  ('Total_Round', '2020 Revenue', 'Latest Net Income'): 0.0014708777666719477,
#  ('Total_Round', '2020 Revenue', 'PE_Backed_Yes'): 0.0014205772379214082,
#  ('Total_Round', '2020 Revenue', 'VC_Backed_Yes'): 0.0013840837853515068,
#  ('Total_Round', '2019 Revenue', 'CAGR'): 0.0013802746399483577,
#  ('Total_Round', '2019 Revenue', 'Latest EBITDA'): 0.0014295981063329652,
#  ('Total_Round', '2019 Revenue', 'Latest EV'): 0.000987935179930058,
#  ('Total_Round', '2019 Revenue', 'Latest Net Income'): 0.0014158312663006517,
#  ('Total_Round', '2019 Revenue', 'PE_Backed_Yes'): 0.0013659263767651453,
#  ('Total_Round', '2019 Revenue', 'VC_Backed_Yes'): 0.00134839024589102,
#  ('Total_Round', 'CAGR', 'Latest EBITDA'): 0.0014058773859899807,
#  ('Total_Round', 'CAGR', 'Latest EV'): 0.0009853246494992765,
#  ('Total_Round', 'CAGR', 'Latest Net Income'): 0.001385798310294689,
#  ('Total_Round', 'CAGR', 'PE_Backed_Yes'): 0.0014241711613886064,
#  ('Total_Round', 'CAGR', 'VC_Backed_Yes'): 0.0014192344825234005,
#  ('Total_Round', 'Latest EBITDA', 'Latest EV'): 0.0009859055066730128,
#  ('Total_Round', 'Latest EBITDA', 'Latest Net Income'): 0.0014226493027618254,
#  ('Total_Round', 'Latest EBITDA', 'PE_Backed_Yes'): 0.0013991726594892464,
#  ('Total_Round', 'Latest EBITDA', 'VC_Backed_Yes'): 0.0013725095369559882,
#  ('Total_Round', 'Latest EV', 'Latest Net Income'): 0.0009919258335439889,
#  ('Total_Round', 'Latest EV', 'PE_Backed_Yes'): 0.0009960239562641522,
#  ('Total_Round', 'Latest EV', 'VC_Backed_Yes'): 0.000961006485086374,
#  ('Total_Round', 'Latest Net Income', 'PE_Backed_Yes'): 0.0013788488027930519,
#  ('Total_Round', 'Latest Net Income', 'VC_Backed_Yes'): 0.0013528147508300962,
#  ('Total_Round', 'PE_Backed_Yes', 'VC_Backed_Yes'): 0.

#   'Latest EBITDA',
#   'Latest Net Income'): 0.0015448676700546404,
#  ('3 Year Revenue Growth',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0014770785516178507,
#  ('3 Year Revenue Growth',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.001491666989033045,
#  ('3 Year Revenue Growth',
#   'Latest EV',
#   'Latest Net Income'): 0.0011127767171990755,
#  ('3 Year Revenue Growth',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0010707465772682651,
#  ('3 Year Revenue Growth',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0010309443369084063,
#  ('3 Year Revenue Growth',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0014619637977186385,
#  ('3 Year Revenue Growth',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0014749427708377438,
#  ('3 Year Revenue Growth',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0014960946305269652,
#  ('2023 Revenue', '2022 Revenue', '2021 Revenue'): 0.0015036191159313777,
#  ('2023 Revenue', '2022 Revenue', '2020 Revenue'): 0.0014740555651042105,
#  ('2023 Revenue', '2022 Revenue', '2019 Revenue'): 0.0014022369332967555,
#  ('2023 Revenue', '2022 Revenue', 'CAGR'): 0.0014605369230389666,
#  ('2023 Revenue', '2022 Revenue', 'Latest EBITDA'): 0.0015009089005009284,
#  ('2023 Revenue', '2022 Revenue', 'Latest EV'): 0.0011266594883600981,
#  ('2023 Revenue', '2022 Revenue', 'Latest Net Income'): 0.001499843617927306,
#  ('2023 Revenue', '2022 Revenue', 'PE_Backed_Yes'): 0.00141322848745287,
#  ('2023 Revenue', '2022 Revenue', 'VC_Backed_Yes'): 0.0014124227253602612,
#  ('2023 Revenue', '2021 Revenue', '2020 Revenue'): 0.0015115542639749344,
#  ('2023 Revenue', '2021 Revenue', '2019 Revenue'): 0.001483316867698209,
#  ('2023 Revenue', '2021 Revenue', 'CAGR'): 0.001430308109396186,
#  ('2023 Revenue', '2021 Revenue', 'Latest EBITDA'): 0.001397243791093529,
#  ('2023 Revenue', '2021 Revenue', 'Latest EV'): 0.0011197262187052945,
#  ('2023 Revenue', '2021 Revenue', 'Latest Net Income'): 0.0014019597789875836,
#  ('2023 Revenue', '2021 Revenue', 'PE_Backed_Yes'): 0.0013798204281050646,
#  ('2023 Revenue', '2021 Revenue', 'VC_Backed_Yes'): 0.0013820776471212214,
#  ('2023 Revenue', '2020 Revenue', '2019 Revenue'): 0.0014076480965748259,
#  ('2023 Revenue', '2020 Revenue', 'CAGR'): 0.0015166292816584717,
#  ('2023 Revenue', '2020 Revenue', 'Latest EBITDA'): 0.0015656369221393937,
#  ('2023 Revenue', '2020 Revenue', 'Latest EV'): 0.001121564426386754,
#  ('2023 Revenue', '2020 Revenue', 'Latest Net Income'): 0.0015639017665888722,
#  ('2023 Revenue', '2020 Revenue', 'PE_Backed_Yes'): 0.001467029833998604,
#  ('2023 Revenue', '2020 Revenue', 'VC_Backed_Yes'): 0.00146796361082928,
#  ('2023 Revenue', '2019 Revenue', 'CAGR'): 0.0014770245064369097,
#  ('2023 Revenue', '2019 Revenue', 'Latest EBITDA'): 0.0015512455404632763,
#  ('2023 Revenue', '2019 Revenue', 'Latest EV'): 0.0011167616910750246,
#  ('2023 Revenue', '2019 Revenue', 'Latest Net Income'): 0.0015395599211072792,
#  ('2023 Revenue', '2019 Revenue', 'PE_Backed_Yes'): 0.001426750125548501,
#  ('2023 Revenue', '2019 Revenue', 'VC_Backed_Yes'): 0.0014320339636658794,
#  ('2023 Revenue', 'CAGR', 'Latest EBITDA'): 0.0015245764750997587,
#  ('2023 Revenue', 'CAGR', 'Latest EV'): 0.0011181115829137914,
#  ('2023 Revenue', 'CAGR', 'Latest Net Income'): 0.001513100030466269,
#  ('2023 Revenue', 'CAGR', 'PE_Backed_Yes'): 0.0014835649636490288,
#  ('2023 Revenue', 'CAGR', 'VC_Backed_Yes'): 0.0014933682987996269,
#  ('2023 Revenue', 'Latest EBITDA', 'Latest EV'): 0.001120928842971484,
#  ('2023 Revenue', 'Latest EBITDA', 'Latest Net Income'): 0.0015473644949798762,
#  ('2023 Revenue', 'Latest EBITDA', 'PE_Backed_Yes'): 0.0014734388006004573,
#  ('2023 Revenue', 'Latest EBITDA', 'VC_Backed_Yes'): 0.0014759857457696886,
#  ('2023 Revenue', 'Latest EV', 'Latest Net Income'): 0.0011194415504928112,
#  ('2023 Revenue', 'Latest EV', 'PE_Backed_Yes'): 0.0010753280541007885,
#  ('2023 Revenue', 'Latest EV', 'VC_Backed_Yes'): 0.0010252176648647446,
#  ('2023 Revenue', 'Latest Net Income', 'PE_Backed_Yes'): 0.0014629214005933418,
#  ('2023 Revenue', 'Latest Net Income', 'VC_Backed_Yes'): 0.001464929923875855,
#  ('2023 Revenue', 'PE_Backed_Yes', 'VC_Backed_Yes'): 0.0014588735587140532,
#  ('2022 Revenue', '2021 Revenue', '2020 Revenue'): 0.0015141453477032405,
#  ('2022 Revenue', '2021 Revenue', '2019 Revenue'): 0.0013686969964939529,
#  ('2022 Revenue', '2021 Revenue', 'CAGR'): 0.0015056096663883735,
#  ('2022 Revenue', '2021 Revenue', 'Latest EBITDA'): 0.0013798072378266326,
#  ('2022 Revenue', '2021 Revenue', 'Latest EV'): 0.001136878802993459,
#  ('2022 Revenue', '2021 Revenue', 'Latest Net Income'): 0.001463638901034442,
#  ('2022 Revenue', '2021 Revenue', 'PE_Backed_Yes'): 0.0014560142149533553,
#  ('2022 Revenue', '2021 Revenue', 'VC_Backed_Yes'): 0.0014624328133804887,
#  ('2022 Revenue', '2020 Revenue', '2019 Revenue'): 0.0013767726499250704,
#  ('2022 Revenue', '2020 Revenue', 'CAGR'): 0.0014766305168889711,
#  ('2022 Revenue', '2020 Revenue', 'Latest EBITDA'): 0.0015189441766031307,
#  ('2022 Revenue', '2020 Revenue', 'Latest EV'): 0.001128169820167898,
#  ('2022 Revenue', '2020 Revenue', 'Latest Net Income'): 0.001521627674134679,
#  ('2022 Revenue', '2020 Revenue', 'PE_Backed_Yes'): 0.0014277554615985334,
#  ('2022 Revenue', '2020 Revenue', 'VC_Backed_Yes'): 0.0014316031636032532,
#  ('2022 Revenue', '2019 Revenue', 'CAGR'): 0.0013771942390428632,
#  ('2022 Revenue', '2019 Revenue', 'Latest EBITDA'): 0.0014246749667097824,
#  ('2022 Revenue', '2019 Revenue', 'Latest EV'): 0.0011249282837178147,
#  ('2022 Revenue', '2019 Revenue', 'Latest Net Income'): 0.0014236097443878104,
#  ('2022 Revenue', '2019 Revenue', 'PE_Backed_Yes'): 0.0013325737347219021,
#  ('2021 Revenue', 'Latest EBITDA', 'Latest Net Income'): 0.00142975601746342,
#  ('2021 Revenue', 'Latest EBITDA', 'PE_Backed_Yes'): 0.001358476524558941,
#  ('2021 Revenue', 'Latest EBITDA', 'VC_Backed_Yes'): 0.001369893673479476,
#  ('2021 Revenue', 'Latest EV', 'Latest Net Income'): 0.0011286705694345915,
#  ('2021 Revenue', 'Latest EV', 'PE_Backed_Yes'): 0.0010805690934055417,
#  ('2021 Revenue', 'Latest EV', 'VC_Backed_Yes'): 0.0010330987185634233,
#  ('2021 Revenue', 'Latest Net Income', 'PE_Backed_Yes'): 0.0013679025045309052,
#  ('2021 Revenue', 'Latest Net Income', 'VC_Backed_Yes'): 0.0013802949165596494,
#  ('2021 Revenue', 'PE_Backed_Yes', 'VC_Backed_Yes'): 0.0013682082457223406,
#  ('2020 Revenue', '2019 Revenue', 'CAGR'): 0.0014531226612203726,
#  ('2020 Revenue', '2019 Revenue', 'Latest EBITDA'): 0.0015118343711962503,
#  ('2020 Revenue', '2019 Revenue', 'Latest EV'): 0.0011372471535288004,
#  ('2020 Revenue', '2019 Revenue', 'Latest Net Income'): 0.001501816892542166,
#  ('2020 Revenue', '2019 Revenue', 'PE_Backed_Yes'): 0.001403640209700336,
#  ('2020 Revenue', '2019 Revenue', 'VC_Backed_Yes'): 0.001411672607353713,
#  ('2020 Revenue', 'CAGR', 'Latest EBITDA'): 0.0016021037999730085,
#  ('2020 Revenue', 'CAGR', 'Latest EV'): 0.001126289859839789,
#  ('2020 Revenue', 'CAGR', 'Latest Net Income'): 0.0015939925201501393,
#  ('2020 Revenue', 'CAGR', 'PE_Backed_Yes'): 0.001503557892874717,
#  ('2020 Revenue', 'CAGR', 'VC_Backed_Yes'): 0.0015149870027743434,
#  ('2020 Revenue', 'Latest EBITDA', 'Latest EV'): 0.0011218936462120833,
#  ('2020 Revenue', 'Latest EBITDA', 'Latest Net Income'): 0.001608171102755629,
#  ('2020 Revenue', 'Latest EBITDA', 'PE_Backed_Yes'): 0.0015487593721251521,
#  ('2020 Revenue', 'Latest EBITDA', 'VC_Backed_Yes'): 0.001557809695426219,
#  ('2020 Revenue', 'Latest EV', 'Latest Net Income'): 0.0011333320291845605,
#  ('2020 Revenue', 'Latest EV', 'PE_Backed_Yes'): 0.0010810032743272112,
#  ('2020 Revenue', 'Latest EV', 'VC_Backed_Yes'): 0.0010341628553676193,
#  ('2020 Revenue', 'Latest Net Income', 'PE_Backed_Yes'): 0.0015415533200098933,
#  ('2020 Revenue', 'Latest Net Income', 'VC_Backed_Yes'): 0.001548935364005489,
#  ('2020 Revenue', 'PE_Backed_Yes', 'VC_Backed_Yes'): 0.0014795268691697569,
#  ('2019 Revenue', 'CAGR', 'Latest EBITDA'): 0.0015769181596640013,
#  ('2019 Revenue', 'CAGR', 'Latest EV'): 0.0011220157823660514,
#  ('2019 Revenue', 'CAGR', 'Latest Net Income'): 0.0015633162770758145,
#  ('2019 Revenue', 'CAGR', 'PE_Backed_Yes'): 0.0014672222439882753,
#  ('2019 Revenue', 'CAGR', 'VC_Backed_Yes'): 0.0014839716869474808,
#  ('2019 Revenue', 'Latest EBITDA', 'Latest EV'): 0.0011215527983801158,
#  ('2019 Revenue', 'Latest EBITDA', 'Latest Net Income'): 0.0015796110120878289,
#  ('2019 Revenue', 'Latest EBITDA', 'PE_Backed_Yes'): 0.

#  ('year_founded',
#   'Total_Round',
#   '2023 Revenue',
#   'CAGR'): 0.0014521523121943446,
#  ('year_founded',
#   'Total_Round',
#   '2023 Revenue',
#   'Latest EBITDA'): 0.0014556968118934143,
#  ('year_founded',
#   'Total_Round',
#   '2023 Revenue',
#   'Latest EV'): 0.0010688290708780286,
#  ('year_founded',
#   'Total_Round',
#   '2023 Revenue',
#   'Latest Net Income'): 0.0014385858339691583,
#  ('year_founded',
#   'Total_Round',
#   '2023 Revenue',
#   'PE_Backed_Yes'): 0.0014481808779804382,
#  ('year_founded',
#   'Total_Round',
#   '2023 Revenue',
#   'VC_Backed_Yes'): 0.0014397271882081013,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   '2021 Revenue'): 0.001474879966815256,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   '2020 Revenue'): 0.0014461140858348532,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   '2019 Revenue'): 0.0013599519818707276,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   'CAGR'): 0.0014224563535048314,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   'Latest EBITDA'): 0.0014688599732691912,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   'Latest EV'): 0.0010748170819211231,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   'Latest Net Income'): 0.001462224460427844,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   'PE_Backed_Yes'): 0.001424594214749207,
#  ('year_founded',
#   'Total_Round',
#   '2022 Revenue',
#   'VC_Backed_Yes'): 0.0013871073207031982,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   '2020 Revenue'): 0.001478822552676604,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   '2019 Revenue'): 0.0014210661348525013,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   'CAGR'): 0.0013897250851813842,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   'Latest EBITDA'): 0.0013694033916641331,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   'Latest EV'): 0.001067873303586118,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   'Latest Net Income'): 0.0013759341719718102,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   'PE_Backed_Yes'): 0.0013878228803907468,
#  ('year_founded',
#   'Total_Round',
#   '2021 Revenue',
#   'VC_Backed_Yes'): 0.0013525718324262778,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   '2019 Revenue'): 0.00141939275393406,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   'CAGR'): 0.0015028790521742215,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   'Latest EBITDA'): 0.0015517666994489785,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   'Latest EV'): 0.0010693530869220263,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   'Latest Net Income'): 0.0015413104517220271,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   'PE_Backed_Yes'): 0.0014997221883836982,
#  ('year_founded',
#   'Total_Round',
#   '2020 Revenue',
#   'VC_Backed_Yes'): 0.0014707055220391468,
#  ('year_founded',
#   'Total_Round',
#   '2019 Revenue',
#   'CAGR'): 0.0014415567646118138,
#  ('year_founded',
#   'Total_Round',
#   '2019 Revenue',
#   'Latest EBITDA'): 0.0014922352260956057,
#  ('year_founded',
#   'Total_Round',
#   '2019 Revenue',
#   'Latest EV'): 0.0010639380960319254,
#  ('year_founded',
#   'Total_Round',
#   '2019 Revenue',
#   'Latest Net Income'): 0.0014795837468322445,
#  ('year_founded',
#   'Total_Round',
#   '2019 Revenue',
#   'PE_Backed_Yes'): 0.001435001458819594,
#  ('year_founded',
#   'Total_Round',
#   '2019 Revenue',
#   'VC_Backed_Yes'): 0.0014183119240052647,
#  ('year_founded',
#   'Total_Round',
#   'CAGR',
#   'Latest EBITDA'): 0.0014701588239738042,
#  ('year_founded', 'Total_Round', 'CAGR', 'Latest EV'): 0.0010613919343180898,
#  ('year_founded',
#   'Total_Round',
#   'CAGR',
#   'Latest Net Income'): 0.0014486048281879501,
#  ('year_founded',
#   'Total_Round',
#   'CAGR',
#   'PE_Backed_Yes'): 0.0014790753217510954,
#  ('year_founded',
#   'Total_Round',
#   'CAGR',
#   'VC_Backed_Yes'): 0.001481655708205625,
#  ('year_founded',
#   'Total_Round',
#   'Latest EBITDA',
#   'Latest EV'): 0.0010618543510232266,
#  ('year_founded',
#   'Total_Round',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.001488699214836097,
#  ('year_founded',
#   'Total_Round',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0014657235732260711,
#  ('year_founded',
#   'Total_Round',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.0014477624330154213,
#  ('year_founded',
#   'Total_Round',
#   'Latest EV',
#   'Latest Net Income'): 0.001065680055232575,
#  ('year_founded',
#   'Total_Round',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0010644546246460944,
#  ('year_founded',
#   'Total_Round',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.001030333785367729,
#  ('year_founded',
#   'Total_Round',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0014446264593942584,
#  ('year_founded',
#   'Total_Round',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0014312498058173847,
#  ('year_founded',
#   'Total_Round',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0014728534538401973,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue'): 0.0014633549226057412,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue'): 0.0014304920534213175,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue'): 0.0015126218724928167,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   '2019 Revenue'): 0.0014747738727074206,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   'CAGR'): 0.0015311293211303135,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   'Latest EBITDA'): 0.0015200200706752306,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   'Latest EV'): 0.0011180542283107616,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   'Latest Net Income'): 0.001507962043856608,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '2023 Revenue',
#   'PE_Backed_Yes'): 0.001487457605350655,
#  ('year_founded',
#   '3 Year Revenue Growth',
#   '

#   '2019 Revenue',
#   'Latest EBITDA'): 0.0014118449954420276,
#  ('Total_Round',
#   '2023 Revenue',
#   '2019 Revenue',
#   'Latest EV'): 0.0009967280388032689,
#  ('Total_Round',
#   '2023 Revenue',
#   '2019 Revenue',
#   'Latest Net Income'): 0.001400971390014157,
#  ('Total_Round',
#   '2023 Revenue',
#   '2019 Revenue',
#   'PE_Backed_Yes'): 0.0013378185001737385,
#  ('Total_Round',
#   '2023 Revenue',
#   '2019 Revenue',
#   'VC_Backed_Yes'): 0.0013079744944987618,
#  ('Total_Round',
#   '2023 Revenue',
#   'CAGR',
#   'Latest EBITDA'): 0.001382551638388995,
#  ('Total_Round', '2023 Revenue', 'CAGR', 'Latest EV'): 0.000994650998340828,
#  ('Total_Round',
#   '2023 Revenue',
#   'CAGR',
#   'Latest Net Income'): 0.0013683625955894052,
#  ('Total_Round',
#   '2023 Revenue',
#   'CAGR',
#   'PE_Backed_Yes'): 0.0013765504683554584,
#  ('Total_Round',
#   '2023 Revenue',
#   'CAGR',
#   'VC_Backed_Yes'): 0.0013686530446067571,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EBITDA',
#   'Latest EV'): 0.0009957910592883318,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.0014066154651427754,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0013859778380817373,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.001347296936039436,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EV',
#   'Latest Net Income'): 0.0010000421618212591,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.00100424101093029,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009785628891181362,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0013715744884210605,
#  ('Total_Round',
#   '2023 Revenue',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0013334888027226868,
#  ('Total_Round',
#   '2023 Revenue',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0013568089993581398,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   '2020 Revenue'): 0.0014231786780056449,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   '2019 Revenue'): 0.0012845011392815648,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   'CAGR'): 0.0014030523477995876,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   'Latest EBITDA'): 0.001306022124601842,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   'Latest EV'): 0.0010122027174139787,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   'Latest Net Income'): 0.0013729487808131755,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   'PE_Backed_Yes'): 0.0014077236022901726,
#  ('Total_Round',
#   '2022 Revenue',
#   '2021 Revenue',
#   'VC_Backed_Yes'): 0.0013472522757929498,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   '2019 Revenue'): 0.0012850987404162905,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   'CAGR'): 0.0013644188008784253,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   'Latest EBITDA'): 0.0014219367167775635,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   'Latest EV'): 0.001003054028504996,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   'Latest Net Income'): 0.0014202660256903761,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   'PE_Backed_Yes'): 0.001367955802570503,
#  ('Total_Round',
#   '2022 Revenue',
#   '2020 Revenue',
#   'VC_Backed_Yes'): 0.0013195123277478596,
#  ('Total_Round', '2022 Revenue', '2019 Revenue', 'CAGR'): 0.001274630049900701,
#  ('Total_Round',
#   '2022 Revenue',
#   '2019 Revenue',
#   'Latest EBITDA'): 0.0013333013065518523,
#  ('Total_Round',
#   '2022 Revenue',
#   '2019 Revenue',
#   'Latest EV'): 0.0009991927280913662,
#  ('Total_Round',
#   '2022 Revenue',
#   '2019 Revenue',
#   'Latest Net Income'): 0.0013304091977871847,
#  ('Total_Round',
#   '2022 Revenue',
#   '2019 Revenue',
#   'PE_Backed_Yes'): 0.0012809503660921205,
#  ('Total_Round',
#   '2022 Revenue',
#   '2019 Revenue',
#   'VC_Backed_Yes'): 0.0012300552220824408,
#  ('Total_Round',
#   '2022 Revenue',
#   'CAGR',
#   'Latest EBITDA'): 0.0013891950537020272,
#  ('Total_Round', '2022 Revenue', 'CAGR', 'Latest EV'): 0.0010012121117440546,
#  ('Total_Round',
#   '2022 Revenue',
#   'CAGR',
#   'Latest Net Income'): 0.0013862782319448614,
#  ('Total_Round',
#   '2022 Revenue',
#   'CAGR',
#   'PE_Backed_Yes'): 0.0013451961968954159,
#  ('Total_Round',
#   '2022 Revenue',
#   'CAGR',
#   'VC_Backed_Yes'): 0.0012986705171064573,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EBITDA',
#   'Latest EV'): 0.000997585506061715,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.0014040031394211537,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0013930478381820547,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.001340091345283531,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EV',
#   'Latest Net Income'): 0.0010035779812278974,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0010108549451261848,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.000979141040119476,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0013912417586084327,
#  ('Total_Round',
#   '2022 Revenue',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0013367578375119461,
#  ('Total_Round',
#   '2022 Revenue',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.001288565973293949,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   '2019 Revenue'): 0.0013081125417411725,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   'CAGR'): 0.0014101066235133143,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   'Latest EBITDA'): 0.0013519024950497554,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   'Latest EV'): 0.0010117573321361407,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   'Latest Net Income'): 0.0013860117939095595,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   'PE_Backed_Yes'): 0.0014085963751918657,
#  ('Total_Round',
#   '2021 Revenue',
#   '2020 Revenue',
#   'VC_Backed_Yes'): 0.0013570456727237873,
#  ('Total_Round',
#   '2021 Revenue',
#   '2019 Revenue',
#   'CAGR'): 0.0013552782153429352,
#  ('Total_Round',
#   '2021 Revenue',
#   '2019 Revenue',
#   'Latest EBITDA'): 0.001343151106799254,
#  ('Total_Round',
#   '2021 Revenue',
#   '2019 Revenue',
#   'Latest EV'): 0.0010071024845346491,
#  ('Total_Round',
#   '2021 Revenue',
#   '2019 Revenue',
#   'Latest Net Income'): 0.001349312591160259,
#  ('Total_Round',
#   '2021 Revenue',
#   '2019 Revenue',
#   'PE_Backed_Yes'): 0.0013521967534128776,
#  ('Total_Round',
#   '2021 Revenue',
#   '2019 Revenue',
#   'VC_Backed_Yes'): 0.001316327701051164,
#  ('Total_Round',
#   '2021 Revenue',
#   'CAGR',
#   'Latest EBITDA'): 0.0012993357869631958,
#  ('Total_Round', '2021 Revenue', 'CAGR', 'Latest EV'): 0.00099508138609053,
#  ('Total_Round',
#   '2021 Revenue',
#   'CAGR',
#   'Latest Net Income'): 0.00130549775562078,
#  ('Total_Round',
#   '2021 Revenue',
#   'CAGR',
#   'PE_Backed_Yes'): 0.0013204132030792653,
#  ('Total_Round',
#   '2021 Revenue',
#   'CAGR',
#   'VC_Backed_Yes'): 0.0012781309402461736,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EBITDA',
#   'Latest EV'): 0.001001631883602598,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.0013150740947858617,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0012926470614377976,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.0012616574168212245,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EV',
#   'Latest Net Income'): 0.0010031149386600074,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0010052892143034506,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.000968807432307816,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0012993901669995662,
#  ('Total_Round',
#   '2021 Revenue',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0012689708766575093,
#  ('Total_Round',
#   '2021 Revenue',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.00126513831090547,
#  ('Total_Round',
#   '2020 Revenue',
#   '2019 Revenue',
#   'CAGR'): 0.0013358458978564819,
#  ('Total_Round',
#   '2020 Revenue',
#   '2019 Revenue',
#   'Latest EBITDA'): 0.001403814741909952,
#  ('Total_Round',
#   '2020 Revenue',
#   '2019 Revenue',
#   'Latest EV'): 0.0010042943224035726,
#  ('Total_Round',
#   '2020 Revenue',
#   '2019 Revenue',
#   'Latest Net Income'): 0.0013988333215591716,
#  ('Total_Round',
#   '2020 Revenue',
#   '2019 Revenue',
#   'PE_Backed_Yes'): 0.0013350780344061077,
#  ('Total_Round',
#   '2020 Revenue',
#   '2019 Revenue',
#   'VC_Backed_Yes'): 0.0012906531209396287,
#  ('Total_Round',
#   '2020 Revenue',
#   'CAGR',
#   'Latest EBITDA'): 0.0014835756621773052,
#  ('Total_Round', '2020 Revenue', 'CAGR', 'Latest EV'): 0.0009952457494266911,
#  ('Total_Round',
#   '2020 Revenue',
#   'CAGR',
#   'Latest Net Income'): 0.001473691837206861,
#  ('Total_Round',
#   '2020 Revenue',
#   'CAGR',
#   'PE_Backed_Yes'): 0.0014233003012023412,
#  ('Total_Round',
#   '2020 Revenue',
#   'CAGR',
#   'VC_Backed_Yes'): 0.0013865450818120247,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EBITDA',
#   'Latest EV'): 0.0009939234728901858,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.0014981782083338454,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0014782230501559981,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.001430609319466952,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EV',
#   'Latest Net Income'): 0.0010049351206344545,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0010050128501361767,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009710325079598405,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0014702527401308583,
#  ('Total_Round',
#   '2020 Revenue',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0014181912273450736,
#  ('Total_Round',
#   '2020 Revenue',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0013731991157676148,
#  ('Total_Round',
#   '2019 Revenue',
#   'CAGR',
#   'Latest EBITDA'): 0.0014323490572935797,
#  ('Total_Round', '2019 Revenue', 'CAGR', 'Latest EV'): 0.000989114793365764,
#  ('Total_Round',
#   '2019 Revenue',
#   'CAGR',
#   'Latest Net Income'): 0.0014185682598545158,
#  ('Total_Round',
#   '2019 Revenue',
#   'CAGR',
#   'PE_Backed_Yes'): 0.0013684177309628356,
#  ('Total_Round',
#   '2019 Revenue',
#   'CAGR',
#   'VC_Backed_Yes'): 0.0013508804507522307,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EBITDA',
#   'Latest EV'): 0.0009875032151797053,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.0014347636345502866,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.0014254010451392554,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.0013985765399461532,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EV',
#   'Latest Net Income'): 0.0010000870088782185,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0009991479879472,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009648009983022189,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0014128308744045747,
#  ('Total_Round',
#   '2019 Revenue',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0013833870381427787,
#  ('Total_Round',
#   '2019 Revenue',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0013358418461235338,
#  ('Total_Round', 'CAGR', 'Latest EBITDA', 'Latest EV'): 0.0009870779902181543,
#  ('Total_Round',
#   'CAGR',
#   'Latest EBITDA',
#   'Latest Net Income'): 0.0014253508109124155,
#  ('Total_Round',
#   'CAGR',
#   'Latest EBITDA',
#   'PE_Backed_Yes'): 0.001401700556854767,
#  ('Total_Round',
#   'CAGR',
#   'Latest EBITDA',
#   'VC_Backed_Yes'): 0.0013749266104585403,
#  ('Total_Round',
#   'CAGR',
#   'Latest EV',
#   'Latest Net Income'): 0.0009931197176851155,
#  ('Total_Round', 'CAGR', 'Latest EV', 'PE_Backed_Yes'): 0.0009968454594290476,
#  ('Total_Round', 'CAGR', 'Latest EV', 'VC_Backed_Yes'): 0.000962252874610744,
#  ('Total_Round',
#   'CAGR',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0013815219483637078,
#  ('Total_Round',
#   'CAGR',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0013552931507244508,
#  ('Total_Round',
#   'CAGR',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0014054677301171485,
#  ('Total_Round',
#   'Latest EBITDA',
#   'Latest EV',
#   'Latest Net Income'): 0.001032003758062617,
#  ('Total_Round',
#   'Latest EBITDA',
#   'Latest EV',
#   'PE_Backed_Yes'): 0.0009977754504277895,
#  ('Total_Round',
#   'Latest EBITDA',
#   'Latest EV',
#   'VC_Backed_Yes'): 0.0009624292996454609,
#  ('Total_Round',
#   'Latest EBITDA',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0014226657244926417,
#  ('Total_Round',
#   'Latest EBITDA',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0013896430940580663,
#  ('Total_Round',
#   'Latest EBITDA',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0013632146681886697,
#  ('Total_Round',
#   'Latest EV',
#   'Latest Net Income',
#   'PE_Backed_Yes'): 0.0010034560147867497,
#  ('Total_Round',
#   'Latest EV',
#   'Latest Net Income',
#   'VC_Backed_Yes'): 0.0009649988190325063,
#  ('Total_Round',
#   'Latest EV',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0009713338747913949,
#  ('Total_Round',
#   'Latest Net Income',
#   'PE_Backed_Yes',
#   'VC_Backed_Yes'): 0.0013467191619722214,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   '2021 Revenue'): 0.0014861880189644932,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   '2020 Revenue'): 0.0014682995901429386,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   '2019 Revenue'): 0.001411191507965963,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   'CAGR'): 0.0014438274912232743,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   'Latest EBITDA'): 0.001494163166062577,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   'Latest EV'): 0.0011141301319172988,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   'Latest Net Income'): 0.001490218003416713,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   'PE_Backed_Yes'): 0.001402118434507079,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2022 Revenue',
#   'VC_Backed_Yes'): 0.0014046332708635475,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   '2020 Revenue'): 0.0014947174419189168,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   '2019 Revenue'): 0.001471169735964078,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   'CAGR'): 0.001411898960220407,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   'Latest EBITDA'): 0.0013839971100839984,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   'Latest EV'): 0.001110187396868303,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   'Latest Net Income'): 0.0013875516831777944,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   'PE_Backed_Yes'): 0.0013676894723878446,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2021 Revenue',
#   'VC_Backed_Yes'): 0.0013748353930261486,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   '2019 Revenue'): 0.0013932832132628817,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   'CAGR'): 0.0014911647953033918,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   'Latest EBITDA'): 0.0015441505460903602,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   'Latest EV'): 0.0011126513655717435,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   'Latest Net Income'): 0.001542213903277029,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   'PE_Backed_Yes'): 0.0014472054818633147,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2020 Revenue',
#   'VC_Backed_Yes'): 0.0014527773207536423,
#  ('3 Year Revenue Growth',
#   '2023 Revenue',
#   '2019 Revenue',
#   'CAGR'): 0.0014548601928255594,
#  ...}
